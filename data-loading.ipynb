# %% [markdown]
# ## Loading data

# %%
import pandas as pd
import numpy as np

# %%
# Display the dataframe
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
# Read the data
X = pd.read_csv('data/train.csv', index_col='Id')

# Remove rows with missing target, separate target from predictors
X.dropna(axis=0, subset=['SalePrice'], inplace=True)

# Predictor variable y
y = X.SalePrice

# Input variables
X.drop(['SalePrice'], axis=1, inplace=True)

# %%
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour']

# %% [markdown]
# ### Parse date

# %%
# start_time           | end_time         
# 2019-03-29 21:23:12  | 2019-03-30 09:11:13

dt_cols = ['start_time', 'end_time']
df = pd.read_excel('survey.xlsx', parse_date=dt_cols) # turning string into datetime64

# another way: using pd.to_datetime()
format_string = "%m%s%Y %H:%M:%S"
df['end_time'] = pd.to_datetime(df['end_time'], format=format_string)

# %% [markdown]
# ## Preliminary investigation

# %% [markdown]
# ### Basic statistics about df

# %%
X.shape
# Out:
# (1460, 79)

# %%
# Columns
# X.columns

# Types of columns
# X.info() 

# Print out numerical vs categorical columns
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]
categorical_cols = [cname for cname in X.columns if X[cname].dtype == "object"]

categorical_cols[:5]
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour']

# %%
X.describe().round(2) # statiscal summary
# Out:
#        MSSubClass  LotFrontage    LotArea  OverallQual  OverallCond  \
# count      1460.0      1201.00    1460.00      1460.00      1460.00
# mean         56.9        70.05   10516.83         6.10         5.58
# std          42.3        24.28    9981.26         1.38         1.11
# min          20.0        21.00    1300.00         1.00         1.00
# 25%          20.0        59.00    7553.50         5.00         5.00
# 50%          50.0        69.00    9478.50         6.00         5.00
# 75%          70.0        80.00   11601.50         7.00         6.00
# max         190.0       313.00  215245.00        10.00         9.00
#
#        YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# count    1460.00       1460.00     1452.00     1460.00     1460.00    1460.00
# mean     1971.27       1984.87      103.69      443.64       46.55     567.24
# std        30.20         20.65      181.07      456.10      161.32     441.87
# ...

# %% [markdown]
# ### Read specific rows, cols, cells

# %%
# Read specific row(s)
X[0:4] # read the first four rows
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5       2003
# 2        Norm     1Fam     1Story            6            8       1976
# ...

# %%
# Read specific location

# X[column_name][row_index]
X['LotArea'][4] # fifth row of column LotArea

# X.loc[row_index][column_name]
X.loc[4]['LotArea']

# X.iloc[row_index, column_number] or X.iloc[row_index][column_name]
X.iloc[2,3]
X.iloc[2]['LotArea']
# Out:
# 11250

# %%
# Read specific column(s)
X[['LotArea', 'Street']][:5]

# REMEMBER:
# df['LotArea'] or df.LotArea --> series
# df[['LotArea']] --> DataFrame
# Out:
#     LotArea Street
# Id
# 1      8450   Pave
# 2      9600   Pave
# 3     11250   Pave
# 4      9550   Pave
# 5     14260   Pave

# %% [markdown]
# ### Distinct values in specific columns

# %%
# Get all unique values of a specific column
print(X['LotShape'].unique())

# Number of unique values
print(X['LotShape'].nunique())
# Out:
# ['Reg' 'IR1' 'IR2' 'IR3']
# 4

# %%
X['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
X.Street.value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
X[['LotShape', 'Street']].groupby('LotShape').Street.value_counts().unstack()
# Out:
# Street    Grvl   Pave
# LotShape
# IR1        1.0  483.0
# IR2        1.0   40.0
# IR3        NaN   10.0
# Reg        4.0  921.0
